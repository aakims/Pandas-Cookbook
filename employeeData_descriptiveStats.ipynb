# %%
# importing libraries 
import pandas as pd
import numpy as np

# %%
# importing datset: emplyee.csv AND its description file descriptions/employee_description.csv
empdat = pd.read_csv('data/employee.csv') 
empdesc = pd.read_csv('data/descriptions/employee_description.csv')

# %%
# preview datasets
empdat.head(10)
#empdesc.head()
# Out:
#    UNIQUE_ID                            POSITION_TITLE  \
# 0          0               ASSISTANT DIRECTOR (EX LVL)
# 1          1                         LIBRARY ASSISTANT
# 2          2                            POLICE OFFICER
# 3          3                         ENGINEER/OPERATOR
# 4          4                               ELECTRICIAN
# 5          5                     SENIOR POLICE OFFICER
# 6          6                                  ENGINEER
# 7          7                                 CARPENTER
# 8          8  DEPUTY ASSISTANT DIRECTOR (EXECUTIVE LEV
# 9          9            AIRPORT OPERATIONS COORDINATOR
#
#                        DEPARTMENT  BASE_SALARY                       RACE  \
# 0     Municipal Courts Department     121862.0            Hispanic/Latino
# 1                         Library      26125.0            Hispanic/Latino
# 2   Houston Police Department-HPD      45279.0                      White
# ...

# %%
empdat.dtypes
# Out:
# UNIQUE_ID              int64
# POSITION_TITLE        object
# DEPARTMENT            object
# BASE_SALARY          float64
# RACE                  object
# EMPLOYMENT_TYPE       object
# GENDER                object
# EMPLOYMENT_STATUS     object
# HIRE_DATE             object
# JOB_DATE              object
# dtype: object

# %%
empdat.describe(include = 'all')
# Out:
#           UNIQUE_ID         POSITION_TITLE                     DEPARTMENT  \
# count   2000.000000                   2000                           2000
# unique          NaN                    330                             24
# top             NaN  SENIOR POLICE OFFICER  Houston Police Department-HPD
# freq            NaN                    220                            638
# mean     999.500000                    NaN                            NaN
# std      577.494589                    NaN                            NaN
# min        0.000000                    NaN                            NaN
# 25%      499.750000                    NaN                            NaN
# 50%      999.500000                    NaN                            NaN
# 75%     1499.250000                    NaN                            NaN
# max     1999.000000                    NaN                            NaN
#
#           BASE_SALARY                       RACE EMPLOYMENT_TYPE GENDER  \
# ...

# %%
empdat = empdat.dropna()

# %%
empdat.describe(include='all')
# Out:
#           UNIQUE_ID  POSITION_TITLE                     DEPARTMENT  \
# count   1853.000000            1853                           1853
# unique          NaN             315                             24
# top             NaN  POLICE OFFICER  Houston Police Department-HPD
# freq            NaN             184                            570
# mean     996.941176             NaN                            NaN
# std      579.063094             NaN                            NaN
# min        0.000000             NaN                            NaN
# 25%      489.000000             NaN                            NaN
# 50%      995.000000             NaN                            NaN
# 75%     1501.000000             NaN                            NaN
# max     1999.000000             NaN                            NaN
#
#           BASE_SALARY                       RACE EMPLOYMENT_TYPE GENDER  \
# count     1853.000000                       1853            1853   1853
# ...

# %%
empdat.groupby(['DEPARTMENT'])['BASE_SALARY'].mean().astype('int').sort_values(ascending=False)
# Out:
# DEPARTMENT
# Legal Department                  104959
# Mayor's Office                     86489
# Finance                            80444
# Houston Information Tech Svcs      76112
# City Council                       63829
# Housing and Community Devp.        61387
# Houston Police Department-HPD      60428
# Houston Fire Department (HFD)      59960
# Human Resources Dept.              56311
# City Controller's Office           55711
# Planning & Development             54879
# Houston Airport System (HAS)       53990
# Admn. & Regulatory Affairs         53805
# Municipal Courts Department        53745
# Health & Human Services            51324
# General Services Department        51295
# Public Works & Engineering-PWE     50207
# Houston Emergency Center (HEC)     47107
# Dept of Neighborhoods (DON)        47092
# Fleet Management Department        44790
# Library                            43857
# Solid Waste Management             42761
# ...

# %%
empdat.groupby(['POSITION_TITLE','DEPARTMENT'])['BASE_SALARY'].mean().astype('int').sort_values(ascending=False)
# Out:
# POSITION_TITLE                            DEPARTMENT
# CITY ATTORNEY                             Legal Department                  275000
# ASSOCIATE EMS PHYSICIAN DIRECTOR,MD       Houston Fire Department (HFD)     210588
# DEPUTY DIRECTOR-FINANCE & ADMINISTRATION  Houston Police Department-HPD     199596
# DEPUTY DIRECTOR-AVIATION (EX LVL)         Houston Airport System (HAS)      186192
# CHIEF PHYSICIAN,MD                        Health & Human Services           180416
# DEPUTY DIRECTOR-PUBLIC WORKS (EXECUTIVE   Public Works & Engineering-PWE    178331
# ASSOCIATE EMS PHYSICIAN DIRECTOR          Houston Fire Department (HFD)     165216
# DEPUTY DIRECTOR (EXECUTIVE LEVEL)         Houston Police Department-HPD     163228
#                                           Houston Airport System (HAS)      150416
# ASSISTANT DIRECTOR-PUBLIC WORKS (EXECUTI  Public Works & Engineering-PWE    144044
# DEPUTY DIRECTOR (EXECUTIVE LEVEL)         Admn. & Regulatory Affairs        140416
# ...

# %%
empdat.groupby(['RACE','GENDER'])['BASE_SALARY'].mean().sort_values(ascending=False)
#empdat.groupby(['RACE','GENDER'])['BASE_SALARY'].max().sort_values(ascending=False)
# Out:
# RACE                               GENDER
# White                              Female    66793.352941
#                                    Male      63940.388119
# Others                             Female    63785.000000
# Asian/Pacific Islander             Female    63226.300000
#                                    Male      61033.906667
# American Indian or Alaskan Native  Male      60305.400000
#                                    Female    60238.800000
# Hispanic/Latino                    Male      54767.541538
# Black or African American          Male      51118.867374
#                                    Female    48965.790378
# Hispanic/Latino                    Female    46503.316176
# Others                             Male      38771.000000
# Name: BASE_SALARY, dtype: float64
